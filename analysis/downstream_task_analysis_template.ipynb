# %% [markdown]
# # Setup

# %% [markdown]
# Use this notebook to analyze how psychometric test scores of synthetic personality reflect downstream behaviors for a given LLM.
#
# To run, update the parameters below for the specific model you wish to analyze.

# %%
# independent shaping scores (relative) filepath)
UNIDIMENSIONAL_SHAPING_SCORES = "scored_results/your_scores_here.pkl"

# raw downstream results (relative) filepath
STATUS_UPDATES_DATA = "../results/" + "your_downstream_results_here.pkl"

# AMS results (relative) filepath
AMS_DATA = "../results/" + "your_AMS_results.csv"

# %% [markdown]
# ## Load Dependencies

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr

# %% [markdown]
# ## Constants

# %%
IPIP_SCALE_IDS = [
    "IPIP300-EXT",
    "IPIP300-AGR",
    "IPIP300-CON",
    "IPIP300-NEU",
    "IPIP300-OPE"
]

AMS_SCALE_IDS = [
    "ams-IPIP300-EXT",
    "ams-IPIP300-AGR",
    "ams-IPIP300-CON",
    "ams-IPIP300-NEU",
    "ams-IPIP300-OPE"
]

AMS_SCALE_IDS_2 = [
    "BIG5_Extraversion",
    "BIG5_Agreeableness",
    "BIG5_Conscientiousness",
    "BIG5_Neuroticism",
    "BIG5_Openness"
]

# %% [markdown]
# ## Read in Data

# %%
# independent shaping personality test scores
# 2250 profiles x 300 items = 675k rows
test_scores = pd.read_pickle(UNIDIMENSIONAL_SHAPING_SCORES)

# downstream task social media status updates
# 2250 profiles x 25 repeats = 56,250 rows
status_updates_raw = pd.read_pickle(STATUS_UPDATES_DATA)

# AMS personality predictions based on status updates
# 7 values per profile
ams_predictions_raw = pd.read_csv(AMS_DATA, index_col=0)

# %%
# pre-process status updates data

# consolidate every 25 updates under their prompted personality profile
status_updates = status_updates_raw.groupby('item_preamble_id')['model_output'].agg(list).reset_index()
status_updates['model_output'] = status_updates['model_output'].apply(lambda x: '\n'.join(x))
status_updates.head(1).model_output
# Out:
# 0    1. "Spent the day in the garden planting some ...
# Name: model_output, dtype: object

# %%
status_updates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2250 entries, 0 to 2249
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_preamble_id  2250 non-null   object
#  1   model_output      2250 non-null   object
# dtypes: object(2)
# memory usage: 35.3+ KB

# %%
# pre-process AMS data

# create ID for every 7 rows
ams_predictions_raw['ID'] = ams_predictions_raw.index // 7

# pivot to wide
ams_predictions_wide = ams_predictions_raw.pivot(
    index=['ID', 'user_id'], 
    columns='trait', 
    values='value')

# average AMS scores by shared prompt
# 56,250 rows / 25 repetitions -> 2,250 rows

# group by `item_preamble_id` (labeled `user_id` here)
ams_predictions = ams_predictions_wide.groupby('user_id').agg('mean')

# %%
ams_predictions['user_id'] = ams_predictions.index
ams_predictions
# Out:
# trait                                   Age  BIG5_Agreeableness  \
# user_id
# ext0-agr0-con0-neu0-ope1-d1-su1   43.577030            0.710400
# ext0-agr0-con0-neu0-ope1-d10-su1  37.493776            0.689204
# ext0-agr0-con0-neu0-ope1-d11-su1  30.371848            0.421184
# ext0-agr0-con0-neu0-ope1-d12-su1  34.881288            0.453956
# ext0-agr0-con0-neu0-ope1-d13-su1  36.273739            0.664904
# ...                                     ...                 ...
# ext9-agr0-con0-neu0-ope0-d50-su1  37.217066            0.724972
# ext9-agr0-con0-neu0-ope0-d6-su1   40.345907            0.703024
# ext9-agr0-con0-neu0-ope0-d7-su1   34.066738            0.737880
# ext9-agr0-con0-neu0-ope0-d8-su1   36.526568            0.737352
# ext9-agr0-con0-neu0-ope0-d9-su1   34.585822            0.696588
#
# trait                             BIG5_Conscientiousness  BIG5_Extraversion  \
# user_id
# ext0-agr0-con0-neu0-ope1-d1-su1                 0.663244           0.288300
# ext0-agr0-con0-neu0-ope1-d10-su1                0.628384           0.459060
# ext0-agr0-con0-neu0-ope1-d11-su1                0.481988           0.244660
# ext0-agr0-con0-neu0-ope1-d12-su1                0.540276           0.258296
# ext0-agr0-con0-neu0-ope1-d13-su1                0.631584           0.424552
# ...                                                  ...                ...
# ext9-agr0-con0-neu0-ope0-d50-su1                0.657980           0.681044
# ext9-agr0-con0-neu0-ope0-d6-su1                 0.658444           0.652780
# ext9-agr0-con0-neu0-ope0-d7-su1                 0.628792           0.654608
# ext9-agr0-con0-neu0-ope0-d8-su1                 0.641612           0.720772
# ext9-agr0-con0-neu0-ope0-d9-su1                 0.660204           0.668688
#
# trait                             BIG5_Neuroticism  BIG5_Openness    Female  \
# user_id
# ext0-agr0-con0-neu0-ope1-d1-su1           0.319632       0.554256  0.255863
# ext0-agr0-con0-neu0-ope1-d10-su1          0.325252       0.512500  0.577332
# ext0-agr0-con0-neu0-ope1-d11-su1          0.387648       0.496340  0.124126
# ext0-agr0-con0-neu0-ope1-d12-su1          0.469668       0.459368  0.465200
# ext0-agr0-con0-neu0-ope1-d13-su1          0.355420       0.512788  0.287927
# ...                                            ...            ...       ...
# ext9-agr0-con0-neu0-ope0-d50-su1          0.346496       0.804928  0.865389
# ext9-agr0-con0-neu0-ope0-d6-su1           0.461776       0.787992  0.869430
# ext9-agr0-con0-neu0-ope0-d7-su1           0.320100       0.885108  0.159897
# ext9-agr0-con0-neu0-ope0-d8-su1           0.355876       0.837368  0.578221
# ext9-agr0-con0-neu0-ope0-d9-su1           0.392644       0.871888  0.586715
#
# trait                                                      user_id
# user_id
# ext0-agr0-con0-neu0-ope1-d1-su1    ext0-agr0-con0-neu0-ope1-d1-su1
# ext0-agr0-con0-neu0-ope1-d10-su1  ext0-agr0-con0-neu0-ope1-d10-su1
# ext0-agr0-con0-neu0-ope1-d11-su1  ext0-agr0-con0-neu0-ope1-d11-su1
# ext0-agr0-con0-neu0-ope1-d12-su1  ext0-agr0-con0-neu0-ope1-d12-su1
# ext0-agr0-con0-neu0-ope1-d13-su1  ext0-agr0-con0-neu0-ope1-d13-su1
# ...                                                            ...
# ext9-agr0-con0-neu0-ope0-d50-su1  ext9-agr0-con0-neu0-ope0-d50-su1
# ext9-agr0-con0-neu0-ope0-d6-su1    ext9-agr0-con0-neu0-ope0-d6-su1
# ext9-agr0-con0-neu0-ope0-d7-su1    ext9-agr0-con0-neu0-ope0-d7-su1
# ext9-agr0-con0-neu0-ope0-d8-su1    ext9-agr0-con0-neu0-ope0-d8-su1
# ext9-agr0-con0-neu0-ope0-d9-su1    ext9-agr0-con0-neu0-ope0-d9-su1
#
# [2250 rows x 8 columns]

# %%
# # optional data checks:

# # show number of unique preambles
# test_scores['item_preamble_id'].nunique()

# %% [markdown]
# ## Join Data

# %%
# attach ablation 01 scores to status updates
# create partial IDs for matching
status_updates['partial_id'] = status_updates['item_preamble_id'].str[:-4]
test_scores['partial_id'] = test_scores['item_preamble_id'].str[:-4]
ams_predictions['partial_id'] = ams_predictions['user_id'].str[:-4]

# drop columns
status_updates.drop('item_preamble_id', axis=1, inplace=True)
test_scores.drop('item_preamble_id', axis=1, inplace=True)
ams_predictions.drop('user_id', axis=1, inplace=True)

dfs = [status_updates, test_scores, ams_predictions]
dfs = [df.set_index('partial_id') for df in dfs]
df_grouped = dfs[0].join(dfs[1:])

# %%
# add intended personality level info
LVL_IDS = ["lvl-EXT", "lvl-AGR", "lvl-CON", "lvl-NEU", "lvl-OPE"]
df_grouped['level_info'] = df_grouped.index
df_grouped[LVL_IDS + ["description_id"]] = df_grouped['level_info'].str.split('-', expand=True)

# %%
def extract_integer(text):
    """
    Extract the level integer contained in a string.
    
    Args:
    text: The input string.
    
    Returns:
    The integer found in the string, or None if no integer is found.
    """
    result = ''
    for char in text:
        if char.isdigit():
            result += char
    try:
        return int(result)
    except ValueError:
        return None

# %%
# replace the values of each lvl- column with only the digits they contain
df_grouped[LVL_IDS + ["description_id"]] = df_grouped[LVL_IDS + ["description_id"]].map(extract_integer)

# %%
# peek at new merged dataframe
# should be 2,250 rows
df_grouped
# Out:
#                                                                    model_output  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1   1. "Spent the day in the garden planting some ...
# ext0-agr0-con0-neu0-ope1-d10  1. "Well, folks, another day, another dollar. ...
# ext0-agr0-con0-neu0-ope1-d11  1. Well, another day at work where everyone el...
# ext0-agr0-con0-neu0-ope1-d12  1. "Spent another long day at the restaurant. ...
# ext0-agr0-con0-neu0-ope1-d13  1. "Another day at work. I enjoy the simple ro...
# ...                                                                         ...
# ext9-agr0-con0-neu0-ope0-d50  1. 🌟 Just wrapped up the most exhilarating wor...
# ext9-agr0-con0-neu0-ope0-d6   1. 🌞 Good morning, fabulous friends and family...
# ext9-agr0-con0-neu0-ope0-d7   1. 🎉🚀 Hey, amazing people! Just finished an ex...
# ext9-agr0-con0-neu0-ope0-d8   1. 🎉🌟 Hey everyone! Just got back from a spont...
# ext9-agr0-con0-neu0-ope0-d9   1. 🌟 Hey, beautiful people! Just wrapped up an...
#
#                              item_postamble_id response_scale_id  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1         plk-ipip-0   likert5_numeric
# ext0-agr0-con0-neu0-ope1-d10        plk-ipip-0   likert5_numeric
# ext0-agr0-con0-neu0-ope1-d11        plk-ipip-0   likert5_numeric
# ext0-agr0-con0-neu0-ope1-d12        plk-ipip-0   likert5_numeric
# ext0-agr0-con0-neu0-ope1-d13        plk-ipip-0   likert5_numeric
# ...                                        ...               ...
# ext9-agr0-con0-neu0-ope0-d50        plk-ipip-0   likert5_numeric
# ext9-agr0-con0-neu0-ope0-d6         plk-ipip-0   likert5_numeric
# ext9-agr0-con0-neu0-ope0-d7         plk-ipip-0   likert5_numeric
# ext9-agr0-con0-neu0-ope0-d8         plk-ipip-0   likert5_numeric
# ext9-agr0-con0-neu0-ope0-d9         plk-ipip-0   likert5_numeric
#
#                              response_choice_postamble_id           model_id  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1                          none  gpt-4o-2024-08-06
# ext0-agr0-con0-neu0-ope1-d10                         none  gpt-4o-2024-08-06
# ext0-agr0-con0-neu0-ope1-d11                         none  gpt-4o-2024-08-06
# ext0-agr0-con0-neu0-ope1-d12                         none  gpt-4o-2024-08-06
# ext0-agr0-con0-neu0-ope1-d13                         none  gpt-4o-2024-08-06
# ...                                                   ...                ...
# ext9-agr0-con0-neu0-ope0-d50                         none  gpt-4o-2024-08-06
# ext9-agr0-con0-neu0-ope0-d6                          none  gpt-4o-2024-08-06
# ext9-agr0-con0-neu0-ope0-d7                          none  gpt-4o-2024-08-06
# ext9-agr0-con0-neu0-ope0-d8                          none  gpt-4o-2024-08-06
# ext9-agr0-con0-neu0-ope0-d9                          none  gpt-4o-2024-08-06
#
#                               ipip1  ipip10  ipip100  ipip101  ipip102  ...  \
# partial_id                                                              ...
# ext0-agr0-con0-neu0-ope1-d1       3       5        5        3        1  ...
# ext0-agr0-con0-neu0-ope1-d10      3       5        5        3        2  ...
# ext0-agr0-con0-neu0-ope1-d11      1       5        5        3        3  ...
# ext0-agr0-con0-neu0-ope1-d12      4       5        5        4        3  ...
# ext0-agr0-con0-neu0-ope1-d13      3       5        5        3        2  ...
# ...                             ...     ...      ...      ...      ...  ...
# ext9-agr0-con0-neu0-ope0-d50      1       2        2        1        5  ...
# ext9-agr0-con0-neu0-ope0-d6       1       2        2        1        5  ...
# ext9-agr0-con0-neu0-ope0-d7       2       3        3        1        5  ...
# ext9-agr0-con0-neu0-ope0-d8       1       1        2        1        5  ...
# ext9-agr0-con0-neu0-ope0-d9       1       2        2        1        5  ...
#
#                               BIG5_Neuroticism  BIG5_Openness    Female  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1           0.319632       0.554256  0.255863
# ext0-agr0-con0-neu0-ope1-d10          0.325252       0.512500  0.577332
# ext0-agr0-con0-neu0-ope1-d11          0.387648       0.496340  0.124126
# ext0-agr0-con0-neu0-ope1-d12          0.469668       0.459368  0.465200
# ext0-agr0-con0-neu0-ope1-d13          0.355420       0.512788  0.287927
# ...                                        ...            ...       ...
# ext9-agr0-con0-neu0-ope0-d50          0.346496       0.804928  0.865389
# ext9-agr0-con0-neu0-ope0-d6           0.461776       0.787992  0.869430
# ext9-agr0-con0-neu0-ope0-d7           0.320100       0.885108  0.159897
# ext9-agr0-con0-neu0-ope0-d8           0.355876       0.837368  0.578221
# ext9-agr0-con0-neu0-ope0-d9           0.392644       0.871888  0.586715
#
#                                                 level_info  lvl-EXT  lvl-AGR  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1    ext0-agr0-con0-neu0-ope1-d1        0        0
# ext0-agr0-con0-neu0-ope1-d10  ext0-agr0-con0-neu0-ope1-d10        0        0
# ext0-agr0-con0-neu0-ope1-d11  ext0-agr0-con0-neu0-ope1-d11        0        0
# ext0-agr0-con0-neu0-ope1-d12  ext0-agr0-con0-neu0-ope1-d12        0        0
# ext0-agr0-con0-neu0-ope1-d13  ext0-agr0-con0-neu0-ope1-d13        0        0
# ...                                                    ...      ...      ...
# ext9-agr0-con0-neu0-ope0-d50  ext9-agr0-con0-neu0-ope0-d50        9        0
# ext9-agr0-con0-neu0-ope0-d6    ext9-agr0-con0-neu0-ope0-d6        9        0
# ext9-agr0-con0-neu0-ope0-d7    ext9-agr0-con0-neu0-ope0-d7        9        0
# ext9-agr0-con0-neu0-ope0-d8    ext9-agr0-con0-neu0-ope0-d8        9        0
# ext9-agr0-con0-neu0-ope0-d9    ext9-agr0-con0-neu0-ope0-d9        9        0
#
#                               lvl-CON  lvl-NEU  lvl-OPE  description_id
# partial_id
# ext0-agr0-con0-neu0-ope1-d1         0        0        1               1
# ext0-agr0-con0-neu0-ope1-d10        0        0        1              10
# ext0-agr0-con0-neu0-ope1-d11        0        0        1              11
# ext0-agr0-con0-neu0-ope1-d12        0        0        1              12
# ext0-agr0-con0-neu0-ope1-d13        0        0        1              13
# ...                               ...      ...      ...             ...
# ext9-agr0-con0-neu0-ope0-d50        0        0        0              50
# ext9-agr0-con0-neu0-ope0-d6         0        0        0               6
# ext9-agr0-con0-neu0-ope0-d7         0        0        0               7
# ext9-agr0-con0-neu0-ope0-d8         0        0        0               8
# ext9-agr0-con0-neu0-ope0-d9         0        0        0               9
#
# [2250 rows x 1824 columns]

# %%
group = df_grouped

# %% [markdown]
# # Compute Correlations

# %%
group[IPIP_SCALE_IDS + AMS_SCALE_IDS_2]
# Out:
#                               IPIP300-EXT  IPIP300-AGR  IPIP300-CON  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1      2.383333     3.283333     3.400000
# ext0-agr0-con0-neu0-ope1-d10     2.500000     3.150000     3.083333
# ext0-agr0-con0-neu0-ope1-d11     2.283333     1.900000     2.000000
# ext0-agr0-con0-neu0-ope1-d12     2.733333     3.150000     3.433333
# ext0-agr0-con0-neu0-ope1-d13     2.516667     3.283333     3.483333
# ...                                   ...          ...          ...
# ext9-agr0-con0-neu0-ope0-d50     5.000000     3.633333     3.600000
# ext9-agr0-con0-neu0-ope0-d6      5.000000     3.666667     3.783333
# ext9-agr0-con0-neu0-ope0-d7      4.983333     3.616667     3.850000
# ext9-agr0-con0-neu0-ope0-d8      5.000000     3.666667     3.333333
# ext9-agr0-con0-neu0-ope0-d9      5.000000     3.516667     3.683333
#
#                               IPIP300-NEU  IPIP300-OPE  BIG5_Extraversion  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1      2.850000     1.300000           0.288300
# ext0-agr0-con0-neu0-ope1-d10     3.066667     1.066667           0.459060
# ext0-agr0-con0-neu0-ope1-d11     3.166667     1.033333           0.244660
# ext0-agr0-con0-neu0-ope1-d12     3.550000     1.083333           0.258296
# ext0-agr0-con0-neu0-ope1-d13     2.816667     1.100000           0.424552
# ...                                   ...          ...                ...
# ext9-agr0-con0-neu0-ope0-d50     2.000000     4.233333           0.681044
# ext9-agr0-con0-neu0-ope0-d6      1.866667     4.183333           0.652780
# ext9-agr0-con0-neu0-ope0-d7      1.866667     4.200000           0.654608
# ext9-agr0-con0-neu0-ope0-d8      2.016667     4.016667           0.720772
# ext9-agr0-con0-neu0-ope0-d9      1.866667     4.333333           0.668688
#
#                               BIG5_Agreeableness  BIG5_Conscientiousness  \
# partial_id
# ext0-agr0-con0-neu0-ope1-d1             0.710400                0.663244
# ext0-agr0-con0-neu0-ope1-d10            0.689204                0.628384
# ext0-agr0-con0-neu0-ope1-d11            0.421184                0.481988
# ext0-agr0-con0-neu0-ope1-d12            0.453956                0.540276
# ext0-agr0-con0-neu0-ope1-d13            0.664904                0.631584
# ...                                          ...                     ...
# ext9-agr0-con0-neu0-ope0-d50            0.724972                0.657980
# ext9-agr0-con0-neu0-ope0-d6             0.703024                0.658444
# ext9-agr0-con0-neu0-ope0-d7             0.737880                0.628792
# ext9-agr0-con0-neu0-ope0-d8             0.737352                0.641612
# ext9-agr0-con0-neu0-ope0-d9             0.696588                0.660204
#
#                               BIG5_Neuroticism  BIG5_Openness
# partial_id
# ext0-agr0-con0-neu0-ope1-d1           0.319632       0.554256
# ext0-agr0-con0-neu0-ope1-d10          0.325252       0.512500
# ext0-agr0-con0-neu0-ope1-d11          0.387648       0.496340
# ext0-agr0-con0-neu0-ope1-d12          0.469668       0.459368
# ext0-agr0-con0-neu0-ope1-d13          0.355420       0.512788
# ...                                        ...            ...
# ext9-agr0-con0-neu0-ope0-d50          0.346496       0.804928
# ext9-agr0-con0-neu0-ope0-d6           0.461776       0.787992
# ext9-agr0-con0-neu0-ope0-d7           0.320100       0.885108
# ext9-agr0-con0-neu0-ope0-d8           0.355876       0.837368
# ext9-agr0-con0-neu0-ope0-d9           0.392644       0.871888
#
# [2250 rows x 10 columns]

# %%
# print for pasting (in order of variable_pairs)
correlations = []
p_values = []
for ipip_scale, ams_scale in zip(IPIP_SCALE_IDS, AMS_SCALE_IDS_2):
    corr_coef, p_value = pearsonr(group[ipip_scale], group[ams_scale])
    correlations.append(corr_coef)
    p_values.append(p_value)

print("Pearson Correlation Coefficients (Tested Personality x Downstream Personality):")
for corr in correlations:
    print(f"{corr:.4f}")

print("\np-values:")
for p in p_values:
    print(f"{p:.4f}")
# Out:
# Pearson Correlation Coefficients:
# 0.7785
# 0.8642
# 0.7705
# 0.6683
# 0.6593
#
# p-values:
# 0.0000
# 0.0000
# 0.0000
# 0.0000
# 0.0000

# %%
# Spearman corrs
# print for pasting (in order of variable_pairs)
correlations = []
p_values = []
for prompted_level, observed_level in zip(LVL_IDS, AMS_SCALE_IDS_2):
    # make sure to only use data where level information is present
    subset = group[group[prompted_level] > 0]
    corr_coef, p_value = spearmanr(subset[prompted_level], subset[observed_level])
    correlations.append(corr_coef)
    p_values.append(p_value)

print("Spearman Correlation Coefficients (Prompted Personality Level x Downstream Personality):")
for corr in correlations:
    print(f"{corr:.4f}")

print("\np-values:")
for p in p_values:
    print(f"{p:.4f}")
# Out:
# Spearman Correlation Coefficients:
# 0.8259
# 0.8853
# 0.8114
# 0.7394
# 0.8199
#
# p-values:
# 0.0000
# 0.0000
# 0.0000
# 0.0000
# 0.0000
